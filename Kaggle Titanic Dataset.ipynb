# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
titanic_df= pd.read_csv("train.csv")

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %%
sns.factorplot('Sex', data=titanic_df, kind="count")

# %%
sns.factorplot("Sex",data= titanic_df,hue="Pclass", kind="count")

# %%
sns.factorplot("Pclass",data= titanic_df,hue="Sex", kind="count")

# %%
def ageseprator(passenger):
    sex, age= passenger
    if(age<16):
        return "child"
    else:
        return sex

# %%
titanic_df["person"]=titanic_df[["Sex","Age"]].apply(ageseprator,axis=1)

# %%
titanic_df[0:20]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
sns.factorplot("Pclass",data=titanic_df, kind="count", hue="person")

# %%
titanic_df["Age"].hist()

# %%
titanic_df["Age"].hist(bins=20)
sns.rugplot(titanic_df["Age"])

# %%
titanic_df["person"].value_counts()
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
bb= sns.FacetGrid(titanic_df,hue="Sex",aspect=3)
bb.map(sns.kdeplot,"Age",shade=True)
old=titanic_df["Age"].max()
bb.set(xlim=(0,old))
bb.add_legend()
# Out:
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
bb= sns.FacetGrid(titanic_df,hue="Pclass",aspect=4)
bb.map(sns.kdeplot,"Age",shade=True)
old=titanic_df["Age"].max()
bb.set(xlim=(0,old))
bb.add_legend()
# Out:
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
deck=titanic_df[["Cabin","Pclass"]].dropna()
deck.info()
deck=deck[deck["Cabin"]!="T"]   #Doubt
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204 entries, 1 to 889
# Data columns (total 2 columns):
# Cabin     204 non-null object
# Pclass    204 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 4.8+ KB

# %%
#deck[0:20]
# Out:
#           Cabin  Pclass
# 1           C85       1
# 3          C123       1
# 6           E46       1
# 10           G6       3
# 11         C103       1
# 21          D56       2
# 23           A6       1
# 27  C23 C25 C27       1
# 31          B78       1
# 52          D33       1
# 54          B30       1
# 55          C52       1
# 61          B28       1
# 62          C83       1
# 66          F33       2
# 75        F G73       3
# 88  C23 C25 C27       1
# 92          E31       1
# 96           A5       1
# 97      D10 D12       1

# %%
"""level=[]
pclass=[]

for place, pclass1 in zip(deck["Cabin"],deck["Pclass"]):
    level.append(place[0])
    pclass.append(pclass1)

cbloc=DataFrame(level,pclass)
cbloc.columns=["Cabin","Pclass"]
cbloc.head()
"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-098b546f0456> in <module>()
#       7
#       8 cbloc=DataFrame(level,pclass)
# ----> 9 cbloc.columns=["Cabin","Pclass"]
#      10 cbloc.head()
#
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    2683         try:
#    2684             object.__getattribute__(self, name)
# -> 2685             return object.__setattr__(self, name, value)
#    2686         except AttributeError:
#    2687             pass
#
# pandas\src\properties.pyx in pandas.lib.AxisProperty.__set__ (pandas\lib.c:44748)()
#
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     426
#     427     def _set_axis(self, axis, labels):
# --> 428         self._data.set_axis(axis, labels)
#     429         self._clear_item_cache()
# ...

# %%
"""cbloc.columns=[["Cabin","Pclass"]]
sns.factorplot("Cabin",data=cbloc, kind="count", palette="summer")"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-53a86732c8d7> in <module>()
# ----> 1 cbloc.columns=[["Cabin","Pclass"]]
#       2 sns.factorplot("Cabin",data=cbloc, kind="count", palette="summer")
#
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    2683         try:
#    2684             object.__getattribute__(self, name)
# -> 2685             return object.__setattr__(self, name, value)
#    2686         except AttributeError:
#    2687             pass
#
# pandas\src\properties.pyx in pandas.lib.AxisProperty.__set__ (pandas\lib.c:44748)()
#
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     426
#     427     def _set_axis(self, axis, labels):
# --> 428         self._data.set_axis(axis, labels)
# ...

# %%
"""sns.factorplot("Cabin",data=cbloc, kind="count", palette="winter", hue="Pclass") #till here doubt
#how to implement the above code"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-701c20a2bb9f> in <module>()
# ----> 1 sns.factorplot("Cabin",data=cbloc, kind="count", palette="winter", hue="Pclass") #till here doubt
#       2 #how to implement the above code
#
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3389     # facets to ensure representation of all data in the final plot
#    3390     p = _CategoricalPlotter()
# -> 3391     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3392     order = p.group_names
#    3393     hue_order = p.hue_names
#
# ...

# %%
deck1=titanic_df[["Cabin","Survived","Age","Sex"]].dropna()
deck1=deck1[deck1["Cabin"]!="T"]
deck1.head()
# Out:
#    Cabin  Survived   Age     Sex
# 1    C85         1  38.0  female
# 3   C123         1  35.0  female
# 6    E46         0  54.0    male
# 10    G6         1   4.0  female
# 11  C103         1  58.0  female

# %%
levels=[]
survived=[]
for i in deck1["Cabin"]:
     levels.append(i[0])
deck1["Cabinloc"]=levels
deck1.head()
# Out:
#    Cabin  Survived   Age     Sex cloc  Deckno Cabinloc
# 1    C85         1  38.0  female    C       3        C
# 3   C123         1  35.0  female    C       3        C
# 6    E46         0  54.0    male    E       5        E
# 10    G6         1   4.0  female    G       7        G
# 11  C103         1  58.0  female    C       3        C

# %%
sns.factorplot("Cabin",data=cloc,kind="count",palette="autumn_d")

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# person         891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
sns.factorplot("Embarked",data=titanic_df,kind="count")

# %%
sns.factorplot("Embarked",data=titanic_df,kind="count",hue="Pclass")

# %%
sns.factorplot("Embarked",data=titanic_df,kind="count",hue="person")

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# person         891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
#who was alone and who was with family?

# %%
titanic_df["alone"]=titanic_df["SibSp"]+ titanic_df["Parch"]

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person  alone
# 0      0         A/5 21171   7.2500   NaN        S    male      1
# 1      0          PC 17599  71.2833   C85        C  female      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female      0
# ...

# %%
titanic_df["alone"].loc[titanic_df["alone"]>0]= "With Family"
titanic_df["alone"].loc[titanic_df["alone"]==0]= "Alone"
# Out:
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\pandas\core\indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
titanic_df["alone"][0:20]
# Out:
# 0     With Family
# 1     With Family
# 2           Alone
# 3     With Family
# 4           Alone
# 5           Alone
# 6           Alone
# 7     With Family
# 8     With Family
# 9     With Family
# 10    With Family
# 11          Alone
# 12          Alone
# 13    With Family
# 14          Alone
# 15          Alone
# 16    With Family
# 17          Alone
# 18    With Family
# 19          Alone
# Name: alone, dtype: object

# %%
sns.factorplot("alone",data=titanic_df,kind="count",palette="Blues_d",x_order=["Alone","With Family"])
# Out:
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\seaborn\categorical.py:3367: UserWarning: The `x_order` parameter has been renamed `order`
#   UserWarning)

# %%
#what factor helped someone survive the crash
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# person         891 non-null object
# alone          891 non-null object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 97.5+ KB

# %%
titanic_df["survivor"]=titanic_df["Survived"].map({0:"No",1:"Yes"})

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.factorplot("survivor",data=titanic_df,kind="count", palette="Set1")

# %%
sns.factorplot("Pclass","Survived", data=titanic_df, hue="person")

# %%
titanic_df["money"]=titanic_df["Pclass"].map({1:"rich",2:"middle class",3:"poor"})

# %%
sns.factorplot("Pclass","money", data=titanic_df)

# %%
sns.factorplot("Pclass","Age",data=titanic_df)

# %%
sns.lmplot("Pclass","Age",titanic_df,x_jitter=0.05)

# %%
sns.factorplot("Pclass","Survived",data=titanic_df,hue="person")

# %%
sns.lmplot("Age","Survived",titanic_df)

# %%
sns.lmplot("Age","Survived",titanic_df,hue="Pclass",markers=["x","o","v"])

# %%
gen=[10,20,30,40,50,60,70,80]
sns.lmplot("Age","Survived",titanic_df,hue="Pclass",x_bins=gen,markers=["^","o","v"],palette="Reds_d")

# %%
titanic_df[(titanic_df.Age>=60) & (titanic_df.Age<=70)]
# Out:
#      PassengerId  Survived  Pclass  \
# 33            34         0       2
# 54            55         0       1
# 170          171         0       1
# 252          253         0       1
# 275          276         1       1
# 280          281         0       3
# 326          327         0       3
# 366          367         1       1
# 438          439         0       1
# 456          457         0       1
# 483          484         1       3
# 545          546         0       1
# 555          556         0       1
# 570          571         1       2
# 587          588         1       1
# 625          626         0       1
# 672          673         0       2
# 684          685         0       2
# 694          695         0       1
# 745          746         0       1
# 829          830         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# ...

# %%
titanic_df[titanic_df.Age>=70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked person  \
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C   male
# 116  male  70.5      0      0      370369   7.7500   NaN        Q   male
# 493  male  71.0      0      0    PC 17609  49.5042   NaN        C   male
# 630  male  80.0      0      0       27042  30.0000   A23        S   male
# ...

# %%
sns.lmplot("Age","Survived",titanic_df,hue="Sex",x_bins=gen)

# %%
deck1.cloc[0:20]
deck1.cloc.value_counts()
# Out:
# C    51
# B    45
# D    31
# E    30
# A    12
# F    11
# G     4
# Name: cloc, dtype: int64

# %%
deck1["Deckno"]=deck1["Cabinloc"].map({"A":1,"B":2,"C":3,"D":4,"E":5,"F":6,"G":7})
deck1.head()
# Out:
#    Cabin  Survived   Age     Sex cloc  Deckno Cabinloc
# 1    C85         1  38.0  female    C       3        C
# 3   C123         1  35.0  female    C       3        C
# 6    E46         0  54.0    male    E       5        E
# 10    G6         1   4.0  female    G       7        G
# 11  C103         1  58.0  female    C       3        C

# %%
sns.lmplot(x="Deckno",y="Survived",hue="Sex",data=deck1,x_estimator= np.mean) #why is this not running

# %%
sns.factorplot(x="Deckno",y="Survived",hue="Sex",data=deck1) #why is this not running

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  person        alone  \
# 0      0         A/5 21171   7.2500   NaN        S    male  With Family
# 1      0          PC 17599  71.2833   C85        C  female  With Family
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female        Alone
# ...

# %%
sns.lmplot("alone","Survived",titanic_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-469ada0bdacc> in <module>()
# ----> 1 sns.lmplot("alone","Survived",titanic_df)
#
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\seaborn\linearmodels.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     566     if sharex:
#     567         for ax in facets.axes.flat:
# --> 568             ax.scatter(data[x], np.ones(len(data)) * data[y].mean()).remove()
#     569
#     570     # Draw the regression plot on each facet
#
# C:\Users\Archit Umrao\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
sns.factorplot("alone","Survived",data=titanic_df)
